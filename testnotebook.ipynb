# %% [markdown]
# # Test notebook
#
# This is a test
#
# $$e^{i\pi} = -1$$
#
# Below is a code cell:

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

momentum = np.random.exponential(1, 10000)
eta = np.random.normal(0, 1, 10000)

plt.hist(momentum, np.linspace(0.0, 10, 20), edgecolor='k', linewidth=1.0)
plt.title("Momentum distribution")
# Out:
# Text(0.5, 1.0, 'Momentum distribution')

# %%
plt.hist(eta, np.linspace(-3.0, 3.0, 30),color='r', edgecolor='k', linewidth=1.0)
plt.title("Eta distribution")
# Out:
# Text(0.5, 1.0, 'Eta distribution')
